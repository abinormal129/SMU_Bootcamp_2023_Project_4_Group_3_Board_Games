# %%
# Import modules
from warnings import simplefilter
simplefilter(action='ignore', category=FutureWarning)

# Data science
import pandas as pd
pd.set_option('display.max_columns', None)
import numpy as np

# Visualization imports
import matplotlib.pyplot as plt
import seaborn as sns

# ML Helpers/Metrics
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report, roc_auc_score, roc_curve

# Scaling
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# Algorithms
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier

import unicodedata
import re

# %%
# Read in the 'games' dataset.
df_games = pd.read_csv("data/games.csv")
df_games.sort_values(by="name", ascending=True, ignore_index=True).head()
# Out:
#        id       type name  yearpublished  minplayers  maxplayers  playingtime  \
# 0   42039  boardgame              2004.0         2.0         4.0         40.0
# 1  182991  boardgame              1979.0         2.0         4.0         60.0
# 2  107551  boardgame              2010.0         2.0         2.0         60.0
# 3   87749  boardgame              2006.0         2.0         2.0         60.0
# 4  180080  boardgame                 0.0         2.0         6.0          0.0
#
#    minplaytime  maxplaytime  minage  users_rated  average_rating  \
# 0         40.0         40.0    10.0           10             6.0
# 1         45.0         60.0     5.0            0             0.0
# 2         60.0         60.0    12.0            3             7.0
# 3         60.0         60.0     7.0            1             6.0
# 4          0.0          0.0     0.0            0             0.0
#
#    bayes_average_rating  total_owners  total_traders  total_wanters  \
# 0                   0.0            11              0              1
# 1                   0.0             0              0              0
# 2                   0.0             5              0              2
# 3                   0.0             0              0              1
# 4                   0.0             1              0              0
#
#    total_wishers  total_comments  total_weights  average_weight
# 0              5               1              0             0.0
# 1              0               0              0             0.0
# 2              2               1              0             0.0
# 3              0               0              0             0.0
# 4              0               0              0             0.0

# %%
# Drop duplicated rows.
df_games.drop_duplicates(keep='first', inplace=True, ignore_index=True)
df_games.shape
# Out:
# (79463, 20)

# %%
# Read in the 'top 5000' dataset.
df_top5000 = pd.read_csv("data/top-5000-20190206.csv")
df_top5000.sort_values(by="names", ascending=True, ignore_index=True).head()
# Out:
#    rank                                            bgg_url  game_id  \
# 0  2745  https://boardgamegeek.com/boardgame/153999/and...   153999
# 1  4406  https://boardgamegeek.com/boardgame/853/und-ts...      853
# 2  1764  https://boardgamegeek.com/boardgame/7865/10-da...     7865
# 3  1975  https://boardgamegeek.com/boardgame/22398/10-d...    22398
# 4  1740  https://boardgamegeek.com/boardgame/5867/10-da...     5867
#
#                          names  min_players  max_players  avg_time  min_time  \
# 0  ...and then, we held hands.            2            2        45        30
# 1              ...und tschüss!            4            6        30        30
# 2            10 Days in Africa            2            4        30        20
# 3              10 Days in Asia            2            4        25        25
# 4            10 Days in Europe            2            4        30        30
#
#    max_time  year  avg_rating  geek_rating  num_votes  \
# 0        45  2015     6.18122      5.88182       1590
# 1        30  1997     6.42761      5.68766        305
# 2        30  2003     6.56139      6.11847       1827
# 3        25  2007     6.68566      6.05385       1070
# 4        30  2002     6.60426      6.12848       1709
#
#                                            image_url  \
# 0  https://cf.geekdo-images.com/original/img/bpIX...
# 1  https://cf.geekdo-images.com/original/img/M7UC...
# 2  https://cf.geekdo-images.com/original/img/k0YH...
# 3  https://cf.geekdo-images.com/original/img/MVy_...
# 4  https://cf.geekdo-images.com/original/img/ArgZ...
#
#                                            thumb_url  age  \
# 0  https://cf.geekdo-images.com/thumb/img/myTPnQ4...   12
# 1  https://cf.geekdo-images.com/thumb/img/hTBB5cJ...   10
# 2  https://cf.geekdo-images.com/thumb/img/Kk309Ut...   10
# 3  https://cf.geekdo-images.com/thumb/img/wXw5vxT...   10
# 4  https://cf.geekdo-images.com/thumb/img/KceoH7G...   10
#
#                                             mechanic  owned  \
# 0  Cooperative Play, Hand Management, Point to Po...   3503
# 1                      Simultaneous Action Selection    387
# 2  Hand Management, Route/Network Building, Tile ...   2087
# 3  Hand Management, Route/Network Building, Tile ...   1303
# 4            Hand Management, Route/Network Building   2048
#
#                   category                                           designer  \
# 0  Card Game, Print & Play                       David Chircop, Yannick Massa
# 1                Card Game                                     Martin Wallace
# 2      Educational, Travel                      Alan R. Moon, Aaron Weissblum
# 3      Educational, Travel                      Alan R. Moon, Aaron Weissblum
# 4      Educational, Travel  Grafik Studio Krüger, Alan R. Moon, Aaron Weis...
#
#                    publisher  weight  expands  reimplements  num_fans
# 0              LudiCreations  1.7400      NaN           NaN       113
# 1         Artra Design, Ltd.  1.3000      NaN           NaN         3
# 2           Beautiful Africa  1.3879      NaN           NaN        22
# 3  Out of the Box Publishing  1.4286      NaN           NaN        15
# 4  Out of the Box Publishing  1.3452      NaN           NaN        24

# %%
# Rename 'top 5000' columns to sync with matching 'games' columns.
df_top5000 = df_top5000.rename(columns={"game_id": "id",
                           "names": "name",
                           "min_players": "minplayers",
                           "max_players": "maxplayers",
                           "avg_time": "playingtime",
                           "min_time": "minplaytime",
                           "max_time": "maxplaytime",
                           "year": "yearpublished",
                           "avg_rating": "average_rating",
                           "num_votes": "users_rated",
                           "owned": "total_owners",
                           "weight": "total_weights"})
df_top5000.head()
# Out:
#    rank                                            bgg_url      id  \
# 0     1  https://boardgamegeek.com/boardgame/174430/glo...  174430
# 1     2  https://boardgamegeek.com/boardgame/161936/pan...  161936
# 2     3  https://boardgamegeek.com/boardgame/182028/thr...  182028
# 3     4  https://boardgamegeek.com/boardgame/167791/ter...  167791
# 4     5  https://boardgamegeek.com/boardgame/12333/twil...   12333
#
#                                             name  minplayers  maxplayers  \
# 0                                     Gloomhaven           1           4
# 1                      Pandemic Legacy: Season 1           2           4
# 2  Through the Ages: A New Story of Civilization           2           4
# 3                              Terraforming Mars           1           5
# 4                              Twilight Struggle           2           2
#
#    playingtime  minplaytime  maxplaytime  yearpublished  average_rating  \
# 0          120           60          120           2017         8.91603
# 1           60           60           60           2015         8.65105
# 2          120          120          120           2015         8.55251
# 3          120          120          120           2016         8.39916
# 4          180          120          180           2005         8.32843
#
#    geek_rating  users_rated  \
# 0      8.61793        22367
# 1      8.49375        29726
# 2      8.27103        14790
# 3      8.23172        35253
# 4      8.18051        33489
#
#                                            image_url  \
# 0  https://cf.geekdo-images.com/original/img/lDN3...
# 1  https://cf.geekdo-images.com/original/img/P_Sw...
# 2  https://cf.geekdo-images.com/original/img/1d2h...
# 3  https://cf.geekdo-images.com/original/img/o8z_...
# 4  https://cf.geekdo-images.com/original/img/ZPnn...
#
#                                            thumb_url  age  \
# 0  https://cf.geekdo-images.com/thumb/img/e7GyV4P...   12
# 1  https://cf.geekdo-images.com/thumb/img/WI5NmPd...   13
# 2  https://cf.geekdo-images.com/thumb/img/Ohqc2KT...   14
# 3  https://cf.geekdo-images.com/thumb/img/yFqQ569...   12
# 4  https://cf.geekdo-images.com/thumb/img/mEmeJrI...   13
#
#                                             mechanic  total_owners  \
# 0  Campaign / Battle Card Driven, Cooperative Pla...         36778
# 1  Action Point Allowance System, Cooperative Pla...         47498
# 2  Action Point Allowance System, Auction/Bidding...         18489
# 3  Card Drafting, Hand Management, Set Collection...         45204
# 4  Area Control / Area Influence, Campaign / Batt...         45955
#
#                                             category  \
# 0  Adventure, Exploration, Fantasy, Fighting, Min...
# 1                             Environmental, Medical
# 2                  Card Game, Civilization, Economic
# 3  Economic, Environmental, Industry / Manufactur...
# 4                 Modern Warfare, Political, Wargame
#
#                        designer            publisher  total_weights  expands  \
# 0                Isaac Childres    Cephalofair Games         3.7768      NaN
# 1      Rob Daviau, Matt Leacock    Z-Man Games, Inc.         2.8323      NaN
# 2                Vlaada Chvátil  Czech Games Edition         4.3715      NaN
# 3               Jacob Fryxelius            FryxGames         3.2344      NaN
# 4  Ananda Gupta, Jason Matthews            GMT Games         3.5627      NaN
#
#    reimplements  num_fans
# 0           NaN      4413
# 1       30549.0      2168
# 2       25613.0      1054
# 3           NaN      2718
# 4           NaN      3639

# %%
# Look at publisher counts.
df_top5000.publisher.value_counts().tail(20)
# Out:
# Mystics.nl                    1
# Underground Games Inc. (I)    1
# Cappelen                      1
# Bink Ink LLC                  1
# Lay Waste Games               1
# Beacon Multimedia S.A.        1
# Titan Forge Games             1
# Crowd Games                   1
# Blacklist Games               1
# Ericsson                      1
# Grimpeur                      1
# Mortensen Games               1
# Dark Ice Games                1
# Copag Cards                   1
# Innovention Toys              1
# Frosted Games                 1
# Rightgames RBG SIA            1
# Dagoy                         1
# Jon Sudbury Games             1
# Diset S. A.                   1
# Name: publisher, dtype: int64

# %%
# Look at designer counts.
df_top5000.designer.value_counts()
# Out:
# Reiner Knizia                               114
# (Uncredited)                                 61
# Martin Wallace                               51
# Klaus Teuber                                 37
# none                                         35
#                                            ...
# Uwe Eickert, Gunter Eickert, Dean Halley      1
# Michael Eskue                                 1
# Chris Darden                                  1
# Eric M. Lang, Kevin Wilson                    1
# Jon Perry, Derek Yu                           1
# Name: designer, Length: 2483, dtype: int64

# %%
# Clean and split mechanic, category, and designer columns.
df_top5000['mechanic_count'] = df_top5000.mechanic.apply(lambda x: len(x.split(",")))
df_top5000['mechanic_clean'] = df_top5000.mechanic.apply(lambda x: x.split(",")[0])
df_top5000['category_count'] = df_top5000.category.apply(lambda x: len(x.split(",")))
df_top5000['category_clean'] = df_top5000.category.apply(lambda x: x.split(",")[0])
df_top5000['designer_count'] = df_top5000.designer.apply(lambda x: len(x.split(",")))
df_top5000['designer_clean'] = df_top5000.designer.apply(lambda x: x.split(",")[0])
df_top5000.head()
# Out:
#    rank                                            bgg_url      id  \
# 0     1  https://boardgamegeek.com/boardgame/174430/glo...  174430
# 1     2  https://boardgamegeek.com/boardgame/161936/pan...  161936
# 2     3  https://boardgamegeek.com/boardgame/182028/thr...  182028
# 3     4  https://boardgamegeek.com/boardgame/167791/ter...  167791
# 4     5  https://boardgamegeek.com/boardgame/12333/twil...   12333
#
#                                             name  minplayers  maxplayers  \
# 0                                     Gloomhaven           1           4
# 1                      Pandemic Legacy: Season 1           2           4
# 2  Through the Ages: A New Story of Civilization           2           4
# 3                              Terraforming Mars           1           5
# 4                              Twilight Struggle           2           2
#
#    playingtime  minplaytime  maxplaytime  yearpublished  average_rating  \
# 0          120           60          120           2017         8.91603
# 1           60           60           60           2015         8.65105
# 2          120          120          120           2015         8.55251
# 3          120          120          120           2016         8.39916
# 4          180          120          180           2005         8.32843
#
#    geek_rating  users_rated  \
# 0      8.61793        22367
# 1      8.49375        29726
# 2      8.27103        14790
# 3      8.23172        35253
# 4      8.18051        33489
#
#                                            image_url  \
# 0  https://cf.geekdo-images.com/original/img/lDN3...
# 1  https://cf.geekdo-images.com/original/img/P_Sw...
# 2  https://cf.geekdo-images.com/original/img/1d2h...
# 3  https://cf.geekdo-images.com/original/img/o8z_...
# 4  https://cf.geekdo-images.com/original/img/ZPnn...
#
#                                            thumb_url  age  \
# 0  https://cf.geekdo-images.com/thumb/img/e7GyV4P...   12
# 1  https://cf.geekdo-images.com/thumb/img/WI5NmPd...   13
# 2  https://cf.geekdo-images.com/thumb/img/Ohqc2KT...   14
# 3  https://cf.geekdo-images.com/thumb/img/yFqQ569...   12
# 4  https://cf.geekdo-images.com/thumb/img/mEmeJrI...   13
#
#                                             mechanic  total_owners  \
# 0  Campaign / Battle Card Driven, Cooperative Pla...         36778
# 1  Action Point Allowance System, Cooperative Pla...         47498
# 2  Action Point Allowance System, Auction/Bidding...         18489
# 3  Card Drafting, Hand Management, Set Collection...         45204
# 4  Area Control / Area Influence, Campaign / Batt...         45955
#
#                                             category  \
# 0  Adventure, Exploration, Fantasy, Fighting, Min...
# 1                             Environmental, Medical
# 2                  Card Game, Civilization, Economic
# 3  Economic, Environmental, Industry / Manufactur...
# 4                 Modern Warfare, Political, Wargame
#
#                        designer            publisher  total_weights  expands  \
# 0                Isaac Childres    Cephalofair Games         3.7768      NaN
# 1      Rob Daviau, Matt Leacock    Z-Man Games, Inc.         2.8323      NaN
# 2                Vlaada Chvátil  Czech Games Edition         4.3715      NaN
# 3               Jacob Fryxelius            FryxGames         3.2344      NaN
# 4  Ananda Gupta, Jason Matthews            GMT Games         3.5627      NaN
#
#    reimplements  num_fans  mechanic_count                 mechanic_clean  \
# 0           NaN      4413               9  Campaign / Battle Card Driven
# 1       30549.0      2168               7  Action Point Allowance System
# 2       25613.0      1054               3  Action Point Allowance System
# 3           NaN      2718               6                  Card Drafting
# 4           NaN      3639               5  Area Control / Area Influence
#
#    category_count  category_clean  designer_count   designer_clean
# 0               5       Adventure               1   Isaac Childres
# 1               2   Environmental               2       Rob Daviau
# 2               3       Card Game               1   Vlaada Chvátil
# 3               6        Economic               1  Jacob Fryxelius
# 4               3  Modern Warfare               2     Ananda Gupta

# %%
# Look at new mechanic_clean counts.
df_top5000.mechanic_clean.value_counts()
# Out:
# Dice Rolling                     644
# Area Control / Area Influence    566
# Hand Management                  479
# Card Drafting                    452
# Action Point Allowance System    393
# Cooperative Play                 285
# Auction/Bidding                  278
# Area Movement                    155
# Action / Movement Programming    143
# Hex-and-Counter                  138
# none                             137
# Deck / Pool Building             106
# Campaign / Battle Card Driven     98
# Grid Movement                     97
# Set Collection                    91
# Betting/Wagering                  75
# Modular Board                     70
# Partnerships                      68
# Pattern Building                  56
# Area Enclosure                    50
# Tile Placement                    50
# Chit-Pull System                  49
# Memory                            48
# Commodity Speculation             40
# Acting                            39
# Route/Network Building            34
# Trick-taking                      33
# Pattern Recognition               32
# Simultaneous Action Selection     31
# Press Your Luck                   27
# Worker Placement                  26
# Pick-up and Deliver               24
# Point to Point Movement           22
# Simulation                        19
# Line Drawing                      19
# Paper-and-Pencil                  17
# Variable Player Powers            17
# Roll / Spin and Move              15
# Crayon Rail System                11
# Player Elimination                10
# Area-Impulse                      10
# Storytelling                       8
# Secret Unit Deployment             6
# Role Playing                       6
# Take That                          5
# Voting                             5
# Stock Holding                      5
# Trading                            3
# Rock-Paper-Scissors                3
# Variable Phase Order               3
# Time Track                         2
# Name: mechanic_clean, dtype: int64

# %%
# Look at new category_clean counts.
df_top5000.category_clean.value_counts()
# Out:
# Card Game                  1004
# Economic                    333
# Adventure                   314
# Bluffing                    270
# Abstract Strategy           270
#                            ...
# Zombies                       2
# World War II                  1
# Religious                     1
# Math                          1
# Expansion for Base-game       1
# Name: category_clean, Length: 78, dtype: int64

# %%
# Look at new designer_clean counts.
df_top5000.designer_clean.value_counts().head(20)
# Out:
# Reiner Knizia        118
# (Uncredited)          64
# Martin Wallace        51
# Bruno Cathala         40
# Alan R. Moon          39
# Klaus Teuber          39
# Richard H. Berg       36
# Friedemann Friese     36
# Dean Essig            35
# Michael Schacht       35
# none                  35
# Uwe Rosenberg         33
# Michael Kiesling      32
# Wolfgang Kramer       29
# Stefan Feld           27
# James Ernest          24
# Stefan Dorra          23
# Mike Elliott          23
# Inka Brand            23
# Vlaada Chvátil        23
# Name: designer_clean, dtype: int64

# %%
# Function to clean the name column.
def clean_name(name):
    # Remove special characters and diacritics
    name = unicodedata.normalize('NFD', name).encode('ascii', 'ignore').decode('utf-8')
    # Replace any remaining special characters with the correct letter
    name = re.sub(r'[^a-zA-Z\s]', '', name)
    return name

# %%
# Incorporate the cleaned names into the top 5000 dataset.
df_top5000['name_clean'] = df_top5000['name'].apply(clean_name)
df_top5000.head()
# Out:
#    rank                                            bgg_url      id  \
# 0     1  https://boardgamegeek.com/boardgame/174430/glo...  174430
# 1     2  https://boardgamegeek.com/boardgame/161936/pan...  161936
# 2     3  https://boardgamegeek.com/boardgame/182028/thr...  182028
# 3     4  https://boardgamegeek.com/boardgame/167791/ter...  167791
# 4     5  https://boardgamegeek.com/boardgame/12333/twil...   12333
#
#                                             name  minplayers  maxplayers  \
# 0                                     Gloomhaven           1           4
# 1                      Pandemic Legacy: Season 1           2           4
# 2  Through the Ages: A New Story of Civilization           2           4
# 3                              Terraforming Mars           1           5
# 4                              Twilight Struggle           2           2
#
#    playingtime  minplaytime  maxplaytime  yearpublished  average_rating  \
# 0          120           60          120           2017         8.91603
# 1           60           60           60           2015         8.65105
# 2          120          120          120           2015         8.55251
# 3          120          120          120           2016         8.39916
# 4          180          120          180           2005         8.32843
#
#    geek_rating  users_rated  \
# 0      8.61793        22367
# 1      8.49375        29726
# 2      8.27103        14790
# 3      8.23172        35253
# 4      8.18051        33489
#
#                                            image_url  \
# 0  https://cf.geekdo-images.com/original/img/lDN3...
# 1  https://cf.geekdo-images.com/original/img/P_Sw...
# 2  https://cf.geekdo-images.com/original/img/1d2h...
# 3  https://cf.geekdo-images.com/original/img/o8z_...
# 4  https://cf.geekdo-images.com/original/img/ZPnn...
#
#                                            thumb_url  age  \
# 0  https://cf.geekdo-images.com/thumb/img/e7GyV4P...   12
# 1  https://cf.geekdo-images.com/thumb/img/WI5NmPd...   13
# 2  https://cf.geekdo-images.com/thumb/img/Ohqc2KT...   14
# 3  https://cf.geekdo-images.com/thumb/img/yFqQ569...   12
# 4  https://cf.geekdo-images.com/thumb/img/mEmeJrI...   13
#
#                                             mechanic  total_owners  \
# 0  Campaign / Battle Card Driven, Cooperative Pla...         36778
# 1  Action Point Allowance System, Cooperative Pla...         47498
# 2  Action Point Allowance System, Auction/Bidding...         18489
# 3  Card Drafting, Hand Management, Set Collection...         45204
# 4  Area Control / Area Influence, Campaign / Batt...         45955
#
#                                             category  \
# 0  Adventure, Exploration, Fantasy, Fighting, Min...
# 1                             Environmental, Medical
# 2                  Card Game, Civilization, Economic
# 3  Economic, Environmental, Industry / Manufactur...
# 4                 Modern Warfare, Political, Wargame
#
#                        designer            publisher  total_weights  expands  \
# 0                Isaac Childres    Cephalofair Games         3.7768      NaN
# 1      Rob Daviau, Matt Leacock    Z-Man Games, Inc.         2.8323      NaN
# 2                Vlaada Chvátil  Czech Games Edition         4.3715      NaN
# 3               Jacob Fryxelius            FryxGames         3.2344      NaN
# 4  Ananda Gupta, Jason Matthews            GMT Games         3.5627      NaN
#
#    reimplements  num_fans  mechanic_count                 mechanic_clean  \
# 0           NaN      4413               9  Campaign / Battle Card Driven
# 1       30549.0      2168               7  Action Point Allowance System
# 2       25613.0      1054               3  Action Point Allowance System
# 3           NaN      2718               6                  Card Drafting
# 4           NaN      3639               5  Area Control / Area Influence
#
#    category_count  category_clean  designer_count   designer_clean  \
# 0               5       Adventure               1   Isaac Childres
# 1               2   Environmental               2       Rob Daviau
# 2               3       Card Game               1   Vlaada Chvátil
# 3               6        Economic               1  Jacob Fryxelius
# 4               3  Modern Warfare               2     Ananda Gupta
#
#                                      name_clean
# 0                                    Gloomhaven
# 1                       Pandemic Legacy Season
# 2  Through the Ages A New Story of Civilization
# 3                             Terraforming Mars
# 4                             Twilight Struggle

# %%
# Top 5000 dataset snapshot.
df_top5000.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 32 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   rank            5000 non-null   int64
#  1   bgg_url         5000 non-null   object
#  2   id              5000 non-null   int64
#  3   name            5000 non-null   object
#  4   minplayers      5000 non-null   int64
#  5   maxplayers      5000 non-null   int64
#  6   playingtime     5000 non-null   int64
#  7   minplaytime     5000 non-null   int64
#  8   maxplaytime     5000 non-null   int64
#  9   yearpublished   5000 non-null   int64
#  10  average_rating  5000 non-null   float64
#  11  geek_rating     5000 non-null   float64
#  12  users_rated     5000 non-null   int64
#  13  image_url       5000 non-null   object
#  14  thumb_url       5000 non-null   object
#  15  age             5000 non-null   int64
#  16  mechanic        5000 non-null   object
#  17  total_owners    5000 non-null   int64
#  18  category        5000 non-null   object
#  19  designer        5000 non-null   object
#  20  publisher       5000 non-null   object
#  21  total_weights   5000 non-null   float64
#  22  expands         3 non-null      float64
#  23  reimplements    833 non-null    float64
#  24  num_fans        5000 non-null   int64
#  25  mechanic_count  5000 non-null   int64
#  26  mechanic_clean  5000 non-null   object
#  27  category_count  5000 non-null   int64
#  28  category_clean  5000 non-null   object
#  29  designer_count  5000 non-null   int64
#  30  designer_clean  5000 non-null   object
#  31  name_clean      5000 non-null   object
# dtypes: float64(5), int64(15), object(12)
# memory usage: 1.2+ MB

# %%
# Top 5000 dataset snapshot.
df_top5000['name_clean'] = df_top5000.name_clean.replace('',np.nan,regex = True)
df_top5000.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 32 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   rank            5000 non-null   int64
#  1   bgg_url         5000 non-null   object
#  2   id              5000 non-null   int64
#  3   name            5000 non-null   object
#  4   minplayers      5000 non-null   int64
#  5   maxplayers      5000 non-null   int64
#  6   playingtime     5000 non-null   int64
#  7   minplaytime     5000 non-null   int64
#  8   maxplaytime     5000 non-null   int64
#  9   yearpublished   5000 non-null   int64
#  10  average_rating  5000 non-null   float64
#  11  geek_rating     5000 non-null   float64
#  12  users_rated     5000 non-null   int64
#  13  image_url       5000 non-null   object
#  14  thumb_url       5000 non-null   object
#  15  age             5000 non-null   int64
#  16  mechanic        5000 non-null   object
#  17  total_owners    5000 non-null   int64
#  18  category        5000 non-null   object
#  19  designer        5000 non-null   object
#  20  publisher       5000 non-null   object
#  21  total_weights   5000 non-null   float64
#  22  expands         3 non-null      float64
#  23  reimplements    833 non-null    float64
#  24  num_fans        5000 non-null   int64
#  25  mechanic_count  5000 non-null   int64
#  26  mechanic_clean  5000 non-null   object
#  27  category_count  5000 non-null   int64
#  28  category_clean  5000 non-null   object
#  29  designer_count  5000 non-null   int64
#  30  designer_clean  5000 non-null   object
#  31  name_clean      4988 non-null   object
# dtypes: float64(5), int64(15), object(12)
# memory usage: 1.2+ MB

# %%
# Merge the top 5000 and games datasets.
df = pd.merge(df_top5000, df_games, on=["id"], how="left")
df.head()
# Out:
#    rank                                            bgg_url      id  \
# 0     1  https://boardgamegeek.com/boardgame/174430/glo...  174430
# 1     2  https://boardgamegeek.com/boardgame/161936/pan...  161936
# 2     3  https://boardgamegeek.com/boardgame/182028/thr...  182028
# 3     4  https://boardgamegeek.com/boardgame/167791/ter...  167791
# 4     5  https://boardgamegeek.com/boardgame/12333/twil...   12333
#
#                                           name_x  minplayers_x  maxplayers_x  \
# 0                                     Gloomhaven             1             4
# 1                      Pandemic Legacy: Season 1             2             4
# 2  Through the Ages: A New Story of Civilization             2             4
# 3                              Terraforming Mars             1             5
# 4                              Twilight Struggle             2             2
#
#    playingtime_x  minplaytime_x  maxplaytime_x  yearpublished_x  \
# 0            120             60            120             2017
# 1             60             60             60             2015
# 2            120            120            120             2015
# 3            120            120            120             2016
# 4            180            120            180             2005
#
#    average_rating_x  geek_rating  users_rated_x  \
# 0           8.91603      8.61793          22367
# 1           8.65105      8.49375          29726
# 2           8.55251      8.27103          14790
# 3           8.39916      8.23172          35253
# 4           8.32843      8.18051          33489
#
#                                            image_url  \
# 0  https://cf.geekdo-images.com/original/img/lDN3...
# 1  https://cf.geekdo-images.com/original/img/P_Sw...
# 2  https://cf.geekdo-images.com/original/img/1d2h...
# 3  https://cf.geekdo-images.com/original/img/o8z_...
# 4  https://cf.geekdo-images.com/original/img/ZPnn...
#
#                                            thumb_url  age  \
# 0  https://cf.geekdo-images.com/thumb/img/e7GyV4P...   12
# 1  https://cf.geekdo-images.com/thumb/img/WI5NmPd...   13
# 2  https://cf.geekdo-images.com/thumb/img/Ohqc2KT...   14
# 3  https://cf.geekdo-images.com/thumb/img/yFqQ569...   12
# 4  https://cf.geekdo-images.com/thumb/img/mEmeJrI...   13
#
#                                             mechanic  total_owners_x  \
# 0  Campaign / Battle Card Driven, Cooperative Pla...           36778
# 1  Action Point Allowance System, Cooperative Pla...           47498
# 2  Action Point Allowance System, Auction/Bidding...           18489
# 3  Card Drafting, Hand Management, Set Collection...           45204
# 4  Area Control / Area Influence, Campaign / Batt...           45955
#
#                                             category  \
# 0  Adventure, Exploration, Fantasy, Fighting, Min...
# 1                             Environmental, Medical
# 2                  Card Game, Civilization, Economic
# 3  Economic, Environmental, Industry / Manufactur...
# 4                 Modern Warfare, Political, Wargame
#
#                        designer            publisher  total_weights_x  \
# 0                Isaac Childres    Cephalofair Games           3.7768
# 1      Rob Daviau, Matt Leacock    Z-Man Games, Inc.           2.8323
# 2                Vlaada Chvátil  Czech Games Edition           4.3715
# 3               Jacob Fryxelius            FryxGames           3.2344
# 4  Ananda Gupta, Jason Matthews            GMT Games           3.5627
#
#    expands  reimplements  num_fans  mechanic_count  \
# 0      NaN           NaN      4413               9
# 1      NaN       30549.0      2168               7
# 2      NaN       25613.0      1054               3
# 3      NaN           NaN      2718               6
# 4      NaN           NaN      3639               5
#
#                   mechanic_clean  category_count  category_clean  \
# 0  Campaign / Battle Card Driven               5       Adventure
# 1  Action Point Allowance System               2   Environmental
# 2  Action Point Allowance System               3       Card Game
# 3                  Card Drafting               6        Economic
# 4  Area Control / Area Influence               3  Modern Warfare
#
#    designer_count   designer_clean  \
# 0               1   Isaac Childres
# 1               2       Rob Daviau
# 2               1   Vlaada Chvátil
# 3               1  Jacob Fryxelius
# 4               2     Ananda Gupta
#
#                                      name_clean       type  \
# 0                                    Gloomhaven  boardgame
# 1                       Pandemic Legacy Season   boardgame
# 2  Through the Ages A New Story of Civilization  boardgame
# 3                             Terraforming Mars  boardgame
# 4                             Twilight Struggle  boardgame
#
#                                           name_y  yearpublished_y  \
# 0                                     Gloomhaven           2016.0
# 1                                Pandemic Legacy           2015.0
# 2  Through the Ages: A New Story of Civilization           2015.0
# 3                              Terraforming Mars           2016.0
# 4                              Twilight Struggle           2005.0
#
#    minplayers_y  maxplayers_y  playingtime_y  minplaytime_y  maxplaytime_y  \
# 0           1.0           4.0          120.0           60.0          120.0
# 1           2.0           4.0           60.0           60.0           60.0
# 2           2.0           4.0          240.0          120.0          240.0
# 3           1.0           5.0          180.0          180.0          180.0
# 4           2.0           2.0          180.0          180.0          180.0
#
#    minage  users_rated_y  average_rating_y  bayes_average_rating  \
# 0    12.0            7.0           9.78571               0.00000
# 1    13.0           12.0           7.33333               0.00000
# 2    14.0           12.0           8.91667               0.00000
# 3    12.0           14.0           8.35714               0.00000
# 4    13.0        20113.0           8.33774               8.22186
#
#    total_owners_y  total_traders  total_wanters  total_wishers  \
# 0            42.0            0.0           62.0          476.0
# 1            64.0            0.0          277.0         1853.0
# 2             9.0            0.0           84.0          686.0
# 3             5.0            0.0           37.0          224.0
# 4         26647.0          372.0         1219.0         5865.0
#
#    total_comments  total_weights_y  average_weight
# 0            39.0              5.0          3.2000
# 1            50.0              3.0          3.0000
# 2            23.0              5.0          4.2000
# 3            22.0              6.0          3.8333
# 4          5347.0           2562.0          3.4785

# %%
# Columns in the games dataset that are not in the top 5000 dataset.
[x for x in df_games.columns if x not in df_top5000.columns]
# Out:
# ['type',
#  'minage',
#  'bayes_average_rating',
#  'total_traders',
#  'total_wanters',
#  'total_wishers',
#  'total_comments',
#  'average_weight']

# %%
# Create a new dataframe with selected columns.
cols = ['id',
        'type',
 'minage',
 'bayes_average_rating',
 'total_traders',
 'total_wanters',
 'total_wishers',
 'total_comments',
 'average_weight']
df_games_sub = df_games.loc[:, cols]
df_games_sub.head()
# Out:
#        id       type  minage  bayes_average_rating  total_traders  \
# 0   12333  boardgame    13.0               8.22186            372
# 1  120677  boardgame    12.0               8.14232            132
# 2  102794  boardgame    12.0               8.06886             99
# 3   25613  boardgame    12.0               8.05804            362
# 4    3076  boardgame    12.0               8.04524            795
#
#    total_wanters  total_wishers  total_comments  average_weight
# 0           1219           5865            5347          3.4785
# 1           1586           6277            2526          3.8939
# 2           1476           5600            1700          3.7761
# 3           1084           5075            3378          4.1590
# 4            861           5414            9173          3.2943

# %%
# Re-merge
df = pd.merge(df_top5000, df_games_sub, on=["id"], how="left")
df.head()
# Out:
#    rank                                            bgg_url      id  \
# 0     1  https://boardgamegeek.com/boardgame/174430/glo...  174430
# 1     2  https://boardgamegeek.com/boardgame/161936/pan...  161936
# 2     3  https://boardgamegeek.com/boardgame/182028/thr...  182028
# 3     4  https://boardgamegeek.com/boardgame/167791/ter...  167791
# 4     5  https://boardgamegeek.com/boardgame/12333/twil...   12333
#
#                                             name  minplayers  maxplayers  \
# 0                                     Gloomhaven           1           4
# 1                      Pandemic Legacy: Season 1           2           4
# 2  Through the Ages: A New Story of Civilization           2           4
# 3                              Terraforming Mars           1           5
# 4                              Twilight Struggle           2           2
#
#    playingtime  minplaytime  maxplaytime  yearpublished  average_rating  \
# 0          120           60          120           2017         8.91603
# 1           60           60           60           2015         8.65105
# 2          120          120          120           2015         8.55251
# 3          120          120          120           2016         8.39916
# 4          180          120          180           2005         8.32843
#
#    geek_rating  users_rated  \
# 0      8.61793        22367
# 1      8.49375        29726
# 2      8.27103        14790
# 3      8.23172        35253
# 4      8.18051        33489
#
#                                            image_url  \
# 0  https://cf.geekdo-images.com/original/img/lDN3...
# 1  https://cf.geekdo-images.com/original/img/P_Sw...
# 2  https://cf.geekdo-images.com/original/img/1d2h...
# 3  https://cf.geekdo-images.com/original/img/o8z_...
# 4  https://cf.geekdo-images.com/original/img/ZPnn...
#
#                                            thumb_url  age  \
# 0  https://cf.geekdo-images.com/thumb/img/e7GyV4P...   12
# 1  https://cf.geekdo-images.com/thumb/img/WI5NmPd...   13
# 2  https://cf.geekdo-images.com/thumb/img/Ohqc2KT...   14
# 3  https://cf.geekdo-images.com/thumb/img/yFqQ569...   12
# 4  https://cf.geekdo-images.com/thumb/img/mEmeJrI...   13
#
#                                             mechanic  total_owners  \
# 0  Campaign / Battle Card Driven, Cooperative Pla...         36778
# 1  Action Point Allowance System, Cooperative Pla...         47498
# 2  Action Point Allowance System, Auction/Bidding...         18489
# 3  Card Drafting, Hand Management, Set Collection...         45204
# 4  Area Control / Area Influence, Campaign / Batt...         45955
#
#                                             category  \
# 0  Adventure, Exploration, Fantasy, Fighting, Min...
# 1                             Environmental, Medical
# 2                  Card Game, Civilization, Economic
# 3  Economic, Environmental, Industry / Manufactur...
# 4                 Modern Warfare, Political, Wargame
#
#                        designer            publisher  total_weights  expands  \
# 0                Isaac Childres    Cephalofair Games         3.7768      NaN
# 1      Rob Daviau, Matt Leacock    Z-Man Games, Inc.         2.8323      NaN
# 2                Vlaada Chvátil  Czech Games Edition         4.3715      NaN
# 3               Jacob Fryxelius            FryxGames         3.2344      NaN
# 4  Ananda Gupta, Jason Matthews            GMT Games         3.5627      NaN
#
#    reimplements  num_fans  mechanic_count                 mechanic_clean  \
# 0           NaN      4413               9  Campaign / Battle Card Driven
# 1       30549.0      2168               7  Action Point Allowance System
# 2       25613.0      1054               3  Action Point Allowance System
# 3           NaN      2718               6                  Card Drafting
# 4           NaN      3639               5  Area Control / Area Influence
#
#    category_count  category_clean  designer_count   designer_clean  \
# 0               5       Adventure               1   Isaac Childres
# 1               2   Environmental               2       Rob Daviau
# 2               3       Card Game               1   Vlaada Chvátil
# 3               6        Economic               1  Jacob Fryxelius
# 4               3  Modern Warfare               2     Ananda Gupta
#
#                                      name_clean       type  minage  \
# 0                                    Gloomhaven  boardgame    12.0
# 1                       Pandemic Legacy Season   boardgame    13.0
# 2  Through the Ages A New Story of Civilization  boardgame    14.0
# 3                             Terraforming Mars  boardgame    12.0
# 4                             Twilight Struggle  boardgame    13.0
#
#    bayes_average_rating  total_traders  total_wanters  total_wishers  \
# 0               0.00000            0.0           62.0          476.0
# 1               0.00000            0.0          277.0         1853.0
# 2               0.00000            0.0           84.0          686.0
# 3               0.00000            0.0           37.0          224.0
# 4               8.22186          372.0         1219.0         5865.0
#
#    total_comments  average_weight
# 0            39.0          3.2000
# 1            50.0          3.0000
# 2            23.0          4.2000
# 3            22.0          3.8333
# 4          5347.0          3.4785

# %%
# Complete dataset snapshot.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5000 entries, 0 to 4999
# Data columns (total 40 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   rank                  5000 non-null   int64
#  1   bgg_url               5000 non-null   object
#  2   id                    5000 non-null   int64
#  3   name                  5000 non-null   object
#  4   minplayers            5000 non-null   int64
#  5   maxplayers            5000 non-null   int64
#  6   playingtime           5000 non-null   int64
#  7   minplaytime           5000 non-null   int64
#  8   maxplaytime           5000 non-null   int64
#  9   yearpublished         5000 non-null   int64
#  10  average_rating        5000 non-null   float64
#  11  geek_rating           5000 non-null   float64
#  12  users_rated           5000 non-null   int64
#  13  image_url             5000 non-null   object
#  14  thumb_url             5000 non-null   object
#  15  age                   5000 non-null   int64
#  16  mechanic              5000 non-null   object
#  17  total_owners          5000 non-null   int64
#  18  category              5000 non-null   object
#  19  designer              5000 non-null   object
#  20  publisher             5000 non-null   object
#  21  total_weights         5000 non-null   float64
#  22  expands               3 non-null      float64
#  23  reimplements          833 non-null    float64
#  24  num_fans              5000 non-null   int64
#  25  mechanic_count        5000 non-null   int64
#  26  mechanic_clean        5000 non-null   object
#  27  category_count        5000 non-null   int64
#  28  category_clean        5000 non-null   object
#  29  designer_count        5000 non-null   int64
#  30  designer_clean        5000 non-null   object
#  31  name_clean            4988 non-null   object
#  32  type                  4014 non-null   object
#  33  minage                4014 non-null   float64
#  34  bayes_average_rating  4014 non-null   float64
#  35  total_traders         4014 non-null   float64
#  36  total_wanters         4014 non-null   float64
#  37  total_wishers         4014 non-null   float64
#  38  total_comments        4014 non-null   float64
#  39  average_weight        4014 non-null   float64
# dtypes: float64(12), int64(15), object(13)
# memory usage: 1.6+ MB

# %%
# Read combined dataset to new csv
df.to_csv("board.csv", index=False)
