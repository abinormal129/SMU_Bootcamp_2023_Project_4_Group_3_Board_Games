# %%
# Import modules
from warnings import simplefilter
simplefilter(action='ignore', category=FutureWarning)

# Data science
import pandas as pd
import numpy as np

# Visualization imports
import matplotlib.pyplot as plt
import seaborn as sns

# ML Helpers/Metrics
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report, roc_auc_score, roc_curve

# Scaling
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# Algorithms
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier

# %%
# Read in the 'games' dataset.
df_games = pd.read_csv("data/games.csv")
df_games.sort_values(by="name", ascending=True, ignore_index=True).head()
# Out:
#        id       type name  yearpublished  minplayers  maxplayers  playingtime  \
# 0   42039  boardgame              2004.0         2.0         4.0         40.0
# 1  182991  boardgame              1979.0         2.0         4.0         60.0
# 2  107551  boardgame              2010.0         2.0         2.0         60.0
# 3   87749  boardgame              2006.0         2.0         2.0         60.0
# 4  180080  boardgame                 0.0         2.0         6.0          0.0
#
#    minplaytime  maxplaytime  minage  users_rated  average_rating  \
# 0         40.0         40.0    10.0           10             6.0
# 1         45.0         60.0     5.0            0             0.0
# 2         60.0         60.0    12.0            3             7.0
# 3         60.0         60.0     7.0            1             6.0
# 4          0.0          0.0     0.0            0             0.0
#
#    bayes_average_rating  total_owners  total_traders  total_wanters  \
# 0                   0.0            11              0              1
# 1                   0.0             0              0              0
# 2                   0.0             5              0              2
# 3                   0.0             0              0              1
# 4                   0.0             1              0              0
#
#    total_wishers  total_comments  total_weights  average_weight
# 0              5               1              0             0.0
# 1              0               0              0             0.0
# 2              2               1              0             0.0
# 3              0               0              0             0.0
# 4              0               0              0             0.0

# %%
# 'Games' dataframe snapshot.
df_games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81312 entries, 0 to 81311
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    81312 non-null  int64
#  1   type                  81312 non-null  object
#  2   name                  81271 non-null  object
#  3   yearpublished         81309 non-null  float64
#  4   minplayers            81309 non-null  float64
#  5   maxplayers            81309 non-null  float64
#  6   playingtime           81309 non-null  float64
#  7   minplaytime           81309 non-null  float64
#  8   maxplaytime           81309 non-null  float64
#  9   minage                81309 non-null  float64
#  10  users_rated           81312 non-null  int64
#  11  average_rating        81312 non-null  float64
#  12  bayes_average_rating  81312 non-null  float64
#  13  total_owners          81312 non-null  int64
#  14  total_traders         81312 non-null  int64
#  15  total_wanters         81312 non-null  int64
#  16  total_wishers         81312 non-null  int64
#  17  total_comments        81312 non-null  int64
#  18  total_weights         81312 non-null  int64
#  19  average_weight        81312 non-null  float64
# dtypes: float64(10), int64(8), object(2)
# memory usage: 12.4+ MB

# %%
# Retrieve dataframe column names and shape (as prep for deletion confirmations).
print(df_games.columns)
print(df_games.shape)
# Out:
# Index(['id', 'type', 'name', 'yearpublished', 'minplayers', 'maxplayers',
#        'playingtime', 'minplaytime', 'maxplaytime', 'minage', 'users_rated',
#        'average_rating', 'bayes_average_rating', 'total_owners',
#        'total_traders', 'total_wanters', 'total_wishers', 'total_comments',
#        'total_weights', 'average_weight'],
#       dtype='object')
# (81312, 20)

# %%
# Drop the non-beneficial columns.
df_games = df_games.drop(columns=["total_traders", "total_wanters", "total_wishers"])
df_games.shape
# Out:
# (81312, 17)

# %%
# Drop duplicated rows.
df_games.drop_duplicates(keep='first', inplace=True, ignore_index=True)
df_games.shape
# Out:
# (79463, 17)

# %%
# 'Games' dataframe summary statistics.
df_games.describe()
# Out:
#                   id  yearpublished    minplayers    maxplayers   playingtime  \
# count   79463.000000   79460.000000  79460.000000  79460.000000  79460.000000
# mean    72614.516907    1802.337465      1.989995      5.651359     50.296640
# std     58830.246442     593.904255      0.936143     56.717431    344.224007
# min         1.000000   -3500.000000      0.000000      0.000000      0.000000
# 25%     21594.500000    1984.000000      2.000000      2.000000      5.000000
# 50%     43454.000000    2003.000000      2.000000      4.000000     30.000000
# 75%    129041.500000    2010.000000      2.000000      6.000000     60.000000
# max    184451.000000    2018.000000     99.000000  11299.000000  60120.000000
#
#         minplaytime   maxplaytime        minage   users_rated  average_rating  \
# count  79460.000000  79460.000000  79460.000000  79463.000000    79463.000000
# mean      48.231626     50.296640      6.901850    101.474925        4.146446
# std      335.562391    344.224007      5.044081    841.304430        3.058123
# min        0.000000      0.000000      0.000000      0.000000        0.000000
# 25%        5.000000      5.000000      0.000000      0.000000        0.000000
# 50%       30.000000     30.000000      8.000000      2.000000        5.166670
# 75%       60.000000     60.000000     12.000000     14.000000        6.649730
# max    60120.000000  60120.000000    120.000000  53680.000000       10.000000
#
#        bayes_average_rating  total_owners  total_comments  total_weights  \
# count          79463.000000  79463.000000    79463.000000   79463.000000
# mean               1.036639    182.068661       32.364950      10.440004
# std                2.220574   1134.929841      210.832116      84.798331
# min                0.000000      0.000000        0.000000       0.000000
# 25%                0.000000      1.000000        0.000000       0.000000
# 50%                0.000000      6.000000        1.000000       0.000000
# 75%                0.000000     43.000000        7.000000       2.000000
# max                8.221860  73188.000000    11798.000000    5996.000000
#
#        average_weight
# count    79463.000000
# mean         0.872706
# std          1.159645
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          1.777800
# max          5.000000

# %%
# Read in the 'top 5000' dataset.
df_top5000 = pd.read_csv("data/top-5000-20190206.csv")
df_top5000.sort_values(by="names", ascending=True, ignore_index=True).head()
# Out:
#    rank                                            bgg_url  game_id  \
# 0  2745  https://boardgamegeek.com/boardgame/153999/and...   153999
# 1  4406  https://boardgamegeek.com/boardgame/853/und-ts...      853
# 2  1764  https://boardgamegeek.com/boardgame/7865/10-da...     7865
# 3  1975  https://boardgamegeek.com/boardgame/22398/10-d...    22398
# 4  1740  https://boardgamegeek.com/boardgame/5867/10-da...     5867
#
#                          names  min_players  max_players  avg_time  min_time  \
# 0  ...and then, we held hands.            2            2        45        30
# 1              ...und tschüss!            4            6        30        30
# 2            10 Days in Africa            2            4        30        20
# 3              10 Days in Asia            2            4        25        25
# 4            10 Days in Europe            2            4        30        30
#
#    max_time  year  ...  age  \
# 0        45  2015  ...   12
# 1        30  1997  ...   10
# 2        30  2003  ...   10
# 3        25  2007  ...   10
# 4        30  2002  ...   10
#
#                                             mechanic  owned  \
# 0  Cooperative Play, Hand Management, Point to Po...   3503
# 1                      Simultaneous Action Selection    387
# 2  Hand Management, Route/Network Building, Tile ...   2087
# 3  Hand Management, Route/Network Building, Tile ...   1303
# 4            Hand Management, Route/Network Building   2048
#
#                   category                                           designer  \
# 0  Card Game, Print & Play                       David Chircop, Yannick Massa
# 1                Card Game                                     Martin Wallace
# 2      Educational, Travel                      Alan R. Moon, Aaron Weissblum
# 3      Educational, Travel                      Alan R. Moon, Aaron Weissblum
# 4      Educational, Travel  Grafik Studio Krüger, Alan R. Moon, Aaron Weis...
#
#                    publisher  weight  expands reimplements num_fans
# 0              LudiCreations  1.7400      NaN          NaN      113
# 1         Artra Design, Ltd.  1.3000      NaN          NaN        3
# 2           Beautiful Africa  1.3879      NaN          NaN       22
# 3  Out of the Box Publishing  1.4286      NaN          NaN       15
# 4  Out of the Box Publishing  1.3452      NaN          NaN       24
#
# [5 rows x 25 columns]

# %%
# Top 5000 dataframe snapshot.
df_top5000.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 25 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   rank          5000 non-null   int64
#  1   bgg_url       5000 non-null   object
#  2   game_id       5000 non-null   int64
#  3   names         5000 non-null   object
#  4   min_players   5000 non-null   int64
#  5   max_players   5000 non-null   int64
#  6   avg_time      5000 non-null   int64
#  7   min_time      5000 non-null   int64
#  8   max_time      5000 non-null   int64
#  9   year          5000 non-null   int64
#  10  avg_rating    5000 non-null   float64
#  11  geek_rating   5000 non-null   float64
#  12  num_votes     5000 non-null   int64
#  13  image_url     5000 non-null   object
#  14  thumb_url     5000 non-null   object
#  15  age           5000 non-null   int64
#  16  mechanic      5000 non-null   object
#  17  owned         5000 non-null   int64
#  18  category      5000 non-null   object
#  19  designer      5000 non-null   object
#  20  publisher     5000 non-null   object
#  21  weight        5000 non-null   float64
#  22  expands       3 non-null      float64
#  23  reimplements  833 non-null    float64
#  24  num_fans      5000 non-null   int64
# dtypes: float64(5), int64(12), object(8)
# memory usage: 976.7+ KB

# %%
# Retrieve dataframe column names and shape (as prep for deletion confirmations).
print(df_top5000.columns)
print(df_top5000.shape)
# Out:
# Index(['rank', 'bgg_url', 'game_id', 'names', 'min_players', 'max_players',
#        'avg_time', 'min_time', 'max_time', 'year', 'avg_rating', 'geek_rating',
#        'num_votes', 'image_url', 'thumb_url', 'age', 'mechanic', 'owned',
#        'category', 'designer', 'publisher', 'weight', 'expands',
#        'reimplements', 'num_fans'],
#       dtype='object')
# (5000, 25)

# %%
# Drop the non-beneficial columns.
df_top5000 = df_top5000.drop(columns=["bgg_url", "geek_rating", "num_votes"])
df_top5000.shape
# Out:
# (5000, 22)

# %%
# 'Top 5000' dataframe summary statistics
df_top5000.describe()
# Out:
#               rank        game_id  min_players  max_players      avg_time  \
# count  5000.000000    5000.000000  5000.000000  5000.000000   5000.000000
# mean   2500.500000   99061.150000     2.002200     5.201200    112.777400
# std    1443.520003   82798.023416     0.687815     7.891006    453.828138
# min       1.000000       1.000000     0.000000     0.000000      0.000000
# 25%    1250.750000   13883.750000     2.000000     4.000000     30.000000
# 50%    2500.500000   94607.000000     2.000000     4.000000     60.000000
# 75%    3750.250000  172515.250000     2.000000     6.000000    106.250000
# max    5000.000000  269210.000000     8.000000   200.000000  22500.000000
#
#           min_time      max_time         year   avg_rating          age  \
# count  5000.000000   5000.000000  5000.000000  5000.000000  5000.000000
# mean     77.200400    112.631000  1998.802800     6.999493    10.503600
# std     193.172975    453.852836   141.747928     0.558673     3.093267
# min       0.000000      0.000000 -3000.000000     5.797230     0.000000
# 25%      30.000000     30.000000  2004.000000     6.578540     8.000000
# 50%      45.000000     60.000000  2011.000000     6.940870    12.000000
# 75%      90.000000    100.000000  2015.000000     7.363548    12.000000
# max    6000.000000  22500.000000  2019.000000     9.135150    18.000000
#
#                owned       weight       expands   reimplements     num_fans
# count    5000.000000  5000.000000      3.000000     833.000000  5000.000000
# mean     3414.078400     2.351609  18009.666667   45541.690276   137.982200
# std      7101.823261     0.801568  15009.028094   59862.362096   353.641359
# min        55.000000     0.000000    712.000000      11.000000     0.000000
# 25%       725.000000     1.748475  13220.500000    1927.000000    20.000000
# 50%      1356.000000     2.290250  25729.000000   16986.000000    44.000000
# 75%      3104.000000     2.900000  26658.500000   70323.000000   112.000000
# max    121071.000000     4.884100  27588.000000  268098.000000  5863.000000

# %%
# Determine the number of unique values in each column of the 'games' dataframe.
cat_cols_games = df_games.select_dtypes(exclude=[np.number]).columns

# value counts
for col in cat_cols_games:
    print(col)
    print(df_games[col].nunique())
    print(df_games[col].value_counts())
    print()
# Out:
# type
# 2
# boardgame             68985
# boardgameexpansion    10478
# Name: type, dtype: int64
#
# name
# 76035
#                       16
#                       15
# Grand Prix            11
# Arena                 11
# Waterloo               9
#                       ..
# Hab acht!              1
# Challenge Sudoku       1
# Hamertjesspel          1
# Felsberger Nuggets     1
# Bingo Animal Kids      1
# Name: name, Length: 76035, dtype: int64

# %%
# Determine the number of unique values in each column of the 'top 5000' dataframe.
cat_cols_top5000 = df_top5000.select_dtypes(exclude=[np.number]).columns

# value counts
for col in cat_cols_top5000:
    print(col)
    print(df_top5000[col].nunique())
    print(df_top5000[col].value_counts())
    print()
# Out:
# names
# 4974
# Cosmic Encounter                        4
# Samurai                                 3
# Wizard                                  2
# Barbarossa                              2
# Lord of the Rings: The Confrontation    2
#                                        ..
# The Fury of Dracula                     1
# Stop Thief!                             1
# Dungeon Command: Curse of Undeath       1
# Deckscape: Test Time                    1
# Time Barons                             1
# Name: names, Length: 4974, dtype: int64
#
# image_url
# 5000
# https://cf.geekdo-images.com/original/img/lDN358RgcYvQfYYN6Oy2TXpifyM=/0x0/pic2437871.jpg    1
# https://cf.geekdo-images.com/original/img/jKOPojAUPrX7fHmkj6F0Nxj97M0=/0x0/pic3999734.jpg    1
# https://cf.geekdo-images.com/original/img/0_kz-cMn28Tghu4WDy2ezdXBumc=/0x0/pic78647.jpg      1
# https://cf.geekdo-images.com/original/img/Ss1Aw3ivEwsSVgEAGbjYvpJLncU=/0x0/pic1356415.jpg    1
# https://cf.geekdo-images.com/original/img/SpkV_Xe92K0c6KxkpAlSC9L5J9Q=/0x0/pic4096767.jpg    1
#                                                                                             ..
# https://cf.geekdo-images.com/original/img/dJvR4Na96vM1yhQ4ioyK1jKwV_8=/0x0/pic431734.jpg     1
# https://cf.geekdo-images.com/original/img/ec6esCOb_jQJd8udiFHMqH9jf-4=/0x0/pic276379.jpg     1
# https://cf.geekdo-images.com/original/img/YxWTmTWoDDZJCFmRf2ngpZ5RjYs=/0x0/pic184259.jpg     1
# https://cf.geekdo-images.com/original/img/RJJama3a9_wLenjvKJh58rgxlBE=/0x0/pic451783.jpg     1
# https://cf.geekdo-images.com/original/img/ant34XOU1t3UYaqTJj9obkLzxIM=/0x0/pic3623201.jpg    1
# Name: image_url, Length: 5000, dtype: int64
#
# thumb_url
# 5000
# https://cf.geekdo-images.com/thumb/img/e7GyV4PaNtwmalU-EQAGecwoBSI=/fit-in/200x150/pic2437871.jpg    1
# https://cf.geekdo-images.com/thumb/img/oSmLxa-muj1qvt5NJY5gVF-S3d8=/fit-in/200x150/pic3999734.jpg    1
# https://cf.geekdo-images.com/thumb/img/rHBhernK_vhMYcJPmC7rdyIyL84=/fit-in/200x150/pic78647.jpg      1
# https://cf.geekdo-images.com/thumb/img/tGaEeN7adtxW_12wfkFWdma9qe0=/fit-in/200x150/pic1356415.jpg    1
# https://cf.geekdo-images.com/thumb/img/WsR6ApkTJdyM3v3gCkSW4Chx8VM=/fit-in/200x150/pic4096767.jpg    1
#                                                                                                     ..
# https://cf.geekdo-images.com/thumb/img/uaWWb4RXIhYPxA21m1h8psK4cM4=/fit-in/200x150/pic431734.jpg     1
# https://cf.geekdo-images.com/thumb/img/RPG72eOCYfu7bS66nNvDc3q3EzQ=/fit-in/200x150/pic276379.jpg     1
# https://cf.geekdo-images.com/thumb/img/xQyHTB349-E-QgxBOnQCdGDL9z8=/fit-in/200x150/pic184259.jpg     1
# https://cf.geekdo-images.com/thumb/img/RqZ6CwJEHShUwFtPI0a4OVSKJbA=/fit-in/200x150/pic451783.jpg     1
# https://cf.geekdo-images.com/thumb/img/DW6SIuA9NqTIuQ7dwfjUDgZdMyY=/fit-in/200x150/pic3623201.jpg    1
# Name: thumb_url, Length: 5000, dtype: int64
#
# mechanic
# 2389
# none                                                                       137
# Hex-and-Counter                                                             96
# Hand Management                                                             89
# Dice Rolling, Hex-and-Counter                                               70
# Dice Rolling, Hex-and-Counter, Simulation                                   63
#                                                                           ...
# Card Drafting, Hand Management, Route/Network Building, Stock Holding        1
# Dice Rolling, Player Elimination, Simultaneous Action Selection, Voting      1
# Auction/Bidding, Press Your Luck                                             1
# Auction/Bidding, Betting/Wagering, Variable Player Powers                    1
# Deck / Pool Building, Variable Player Powers                                 1
# Name: mechanic, Length: 2389, dtype: int64
#
# category
# 2264
# Wargame, World War II                       184
# Card Game                                   177
# Abstract Strategy                            97
# Card Game, Fantasy                           69
# Economic                                     57
#                                            ...
# Card Game, Exploration, Science Fiction       1
# Economic, Real-time, Renaissance              1
# Adventure, Comic Book / Strip, Fighting       1
# City Building, Civilization, Negotiation      1
# Card Game, Fantasy, Fighting, Mythology       1
# Name: category, Length: 2264, dtype: int64
#
# designer
# 2483
# Reiner Knizia                               114
# (Uncredited)                                 61
# Martin Wallace                               51
# Klaus Teuber                                 37
# none                                         35
#                                            ...
# Uwe Eickert, Gunter Eickert, Dean Halley      1
# Michael Eskue                                 1
# Chris Darden                                  1
# Eric M. Lang, Kevin Wilson                    1
# Jon Perry, Derek Yu                           1
# Name: designer, Length: 2483, dtype: int64
#
# publisher
# 1014
# GMT Games                  174
# 999 Games                  127
# Asmodee                    110
# The Avalon Hill Game Co     98
# Fantasy Flight Games        88
#                           ...
# Frosted Games                1
# Rightgames RBG SIA           1
# Dagoy                        1
# Jon Sudbury Games            1
# Diset S. A.                  1
# Name: publisher, Length: 1014, dtype: int64

# %%
# merge code example... we may need to use a full "outer" join.
# df = pd.merge(df, team_sub, on=["teamID", "yearID"], how="inner")
# print(df.shape)
# df.head()
